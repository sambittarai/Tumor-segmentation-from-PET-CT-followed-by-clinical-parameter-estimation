# %%
import numpy as np
import matplotlib.pyplot as plt

img = np.load("/media/sambit/HDD/Sambit/Projects/Project_5/GitHub/Tumor-segmentation-from-PET-CT-followed-by-outcome-prediction/Data Preparation/Output/Multi-angled_multi-channel_2D_projections/PETCT_3c71e8f518/12-11-2000-NA-PET-CT Ganzkoerper  primaer mit KM-59350/SUV_MIP/90.npy")
img.shape
# Out:
# (326, 280)

# %%
plt.imshow(img, cmap="gray")
